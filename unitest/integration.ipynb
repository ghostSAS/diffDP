# %%
# import path
import sys
sys.path.append('../')

import autograd.numpy as np
import time as time

from CDDP import *

import visulization.static as vsta
import visulization.animation as vani

sysm = cart_pen

# %% [markdown]
# ### validate ode solver

# %%
x0 = np.random.rand(4)*0+1
u = np.random.rand(1)*0+1
dt = .05

xP = solver.RK4(sysm,x0,u[0],dt)

print( xP)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# C:\Users\YUNSHE~1\AppData\Local\Temp/ipykernel_29708/1985421131.py in <module>
#       3 dt = .05
#       4
# ----> 5 xP = solver.RK4(sysm,x0,u[0],dt)
#       6
#       7 print( xP)
#
# c:\Software\Anaconda\lib\site-packages\numba\core\dispatcher.py in _compile_for_args(self, *args, **kws)
#     466                 e.patch_message(msg)
#     467
# --> 468             error_rewrite(e, 'typing')
#     469         except errors.UnsupportedError as e:
#     470             # Something unsupported is present in the user code, add help info
#
# c:\Software\Anaconda\lib\site-packages\numba\core\dispatcher.py in error_rewrite(e, issue_type)
#     407                 raise e
#     408             else:
# --> 409                 raise e.with_traceback(None)
#     410
#     411         argtypes = []
#
# ...

# %% [markdown]
# ### validate trajectory

# %%
T = 5
dt = .01
N = int(T/dt)-1

U = np.ones((N,1))
x0 = np.random.rand(4)*0+1

tspan = np.linspace(0,T,N+1)

sT = time.time()
traj = solver.get_traj(sysm, x0, U, dt)
print('Time consumed: ' + str(time.time()-sT))

print(traj[-1,:])

vsta.plot_time_series(tspan,traj)
# Out:
# Time consumed: 0.05984044075012207
# [24.16166113 -1.30279261  8.16774195  0.31461641]

# %%
import numpy as np
np.random.rand(1,4)
# Out:
# array([[0.52497781, 0.13232162, 0.20089179, 0.41538828]])
